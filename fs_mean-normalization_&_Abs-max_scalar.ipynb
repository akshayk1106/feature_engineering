# %% [markdown]
# # MEAN NORMALIZATION SCALAR

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# it has no much use as such, but its useful mean centering
#
# instead standardisation can be used for centering the data
#
# @also sklearn has no specific calss for this scalar,
# we ourselves only have to implement it

# %% [markdown]
# # MAX ABOLUTE SCALAR

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# it is useful when the dataset is sparse matrix
